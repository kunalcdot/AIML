# %%
import requests

# %%
r = requests.get('https://www.screener.in/company/ASIANPAINT/consolidated/')

# %%
from web_parser import ParseNCreatedf

# %%
df = ParseNCreatedf(r,'ASIANPAINT')
df
# Out:
#     Stock Name                                                FY   Sales  \
# 0   ASIANPAINT  \n            Mar 2013\n            \n            10,504
# 1   ASIANPAINT  \n            Mar 2014\n            \n            12,220
# 2   ASIANPAINT  \n            Mar 2015\n            \n            13,615
# 3   ASIANPAINT  \n            Mar 2016\n            \n            14,271
# 4   ASIANPAINT  \n            Mar 2017\n            \n            15,062
# 5   ASIANPAINT  \n            Mar 2018\n            \n            16,825
# 6   ASIANPAINT  \n            Mar 2019\n            \n            19,240
# 7   ASIANPAINT  \n            Mar 2020\n            \n            20,211
# 8   ASIANPAINT  \n            Mar 2021\n            \n            21,713
# 9   ASIANPAINT  \n            Mar 2022\n            \n            29,101
# 10  ASIANPAINT  \n            Mar 2023\n            \n            34,489
# 11  ASIANPAINT  \n            Mar 2024\n            \n            35,495
#
# ...

# %%
import pandas as pd
r = requests.get('https://www.screener.in/company/NH/consolidated/')
df1 = ParseNCreatedf(r,'NH')
combined_df = pd.concat([df, df1], ignore_index=True)
combined_df
# Out:
#     Stock Name                                                FY   Sales  \
# 0   ASIANPAINT  \n            Mar 2013\n            \n            10,504
# 1   ASIANPAINT  \n            Mar 2014\n            \n            12,220
# 2   ASIANPAINT  \n            Mar 2015\n            \n            13,615
# 3   ASIANPAINT  \n            Mar 2016\n            \n            14,271
# 4   ASIANPAINT  \n            Mar 2017\n            \n            15,062
# 5   ASIANPAINT  \n            Mar 2018\n            \n            16,825
# 6   ASIANPAINT  \n            Mar 2019\n            \n            19,240
# 7   ASIANPAINT  \n            Mar 2020\n            \n            20,211
# 8   ASIANPAINT  \n            Mar 2021\n            \n            21,713
# 9   ASIANPAINT  \n            Mar 2022\n            \n            29,101
# 10  ASIANPAINT  \n            Mar 2023\n            \n            34,489
# 11  ASIANPAINT  \n            Mar 2024\n            \n            35,495
# ...
