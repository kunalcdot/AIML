# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Sample_Weather_Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.size
# Out:
# 70272

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
#Pandas .count() method is used to show the total number of non-null in each column.
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Wind Speed_km/h'].nunique()# printing number of unique values
# Out:
# 34

# %%
df['Wind Speed_km/h'].unique()# printing unique values
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2],
#       dtype=int64)

# %%
df.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
df.notnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0          True    True              True       True             True
# 1          True    True              True       True             True
# 2          True    True              True       True             True
# 3          True    True              True       True             True
# 4          True    True              True       True             True
# ...         ...     ...               ...        ...              ...
# 8779       True    True              True       True             True
# 8780       True    True              True       True             True
# 8781       True    True              True       True             True
# 8782       True    True              True       True             True
# 8783       True    True              True       True             True
#
#       Visibility_km  Press_kPa  Weather
# 0              True       True     True
# 1              True       True     True
# ...

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
df[df['Weather']=='Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
len(df[df['Weather']=='Clear'])
# Out:
# 1326

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df1 = df[df['Wind Speed_km/h']==4]
df1
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %%
df1['Weather'].unique()
# Out:
# array(['Fog', 'Snow', 'Cloudy', 'Mostly Cloudy', 'Mainly Clear', 'Clear',
#        'Snow,Haze', 'Snow Showers', 'Snow,Fog', 'Rain,Fog', 'Drizzle,Fog',
#        'Freezing Fog', 'Rain Showers', 'Drizzle', 'Thunderstorms,Rain',
#        'Rain'], dtype=object)

# %%
df1[['Date/Time','Weather']]
# Out:
#              Date/Time       Weather
# 0        1/1/2012 0:00           Fog
# 1        1/1/2012 1:00           Fog
# 96       1/5/2012 0:00          Snow
# 101      1/5/2012 5:00          Snow
# 146      1/7/2012 2:00        Cloudy
# ...                ...           ...
# 8768   12/31/2012 8:00  Snow Showers
# 8769   12/31/2012 9:00          Snow
# 8770  12/31/2012 10:00      Snow,Fog
# 8772  12/31/2012 12:00          Snow
# 8773  12/31/2012 13:00          Snow
#
# [474 rows x 2 columns]

# %%
wind_groups = df.groupby('Wind Speed_km/h')
wind_groups.get_group(4)[['Date/Time','Weather']]
# Out:
#              Date/Time       Weather
# 0        1/1/2012 0:00           Fog
# 1        1/1/2012 1:00           Fog
# 96       1/5/2012 0:00          Snow
# 101      1/5/2012 5:00          Snow
# 146      1/7/2012 2:00        Cloudy
# ...                ...           ...
# 8768   12/31/2012 8:00  Snow Showers
# 8769   12/31/2012 9:00          Snow
# 8770  12/31/2012 10:00      Snow,Fog
# 8772  12/31/2012 12:00          Snow
# 8773  12/31/2012 13:00          Snow
#
# [474 rows x 2 columns]

# %%
df = pd.read_csv('indian_food.csv')
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %%
df1 = df[['name','ingredients']]
df1
# Out:
#                name                                        ingredients
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
# [255 rows x 2 columns]

# %%
df2 = df.head(10)
df2
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %% [markdown]
# 1st plotting method using matplotlib.

# %%
x = df2['name']
y = df2['prep_time']
y1 = df2['cook_time']

width = 0.4
cntr_pt = np.arange(len(x))
plt.bar(cntr_pt,y,label='Prep',width = width)
plt.bar(cntr_pt+width,y1,label='Cook',width = width)
plt.xlabel('Name')
plt.xticks(cntr_pt, x) 
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# 2nd plotting method using dataframe directly
# Pandas plot command will be used

# %%
df3 = df2[['name','prep_time','cook_time']]
df3
# Out:
#              name  prep_time  cook_time
# 0      Balu shahi         45         25
# 1          Boondi         80         30
# 2  Gajar ka halwa         15         60
# 3          Ghevar         15         30
# 4     Gulab jamun         15         40
# 5          Imarti         10         50
# 6          Jalebi         10         50
# 7      Kaju katli         10         20
# 8        Kalakand         20         30
# 9           Kheer         10         40

# %%
df3.plot.bar(x='name', rot=45) # plot is part of pandas library
# Out:
# <Axes: xlabel='name'>
