# %%
import numpy as np
X=np.array([1,2,5])
Y=np.array([5,10,30])
m=2
c=0
Y_pred = m*X + c
Y_pred - Y
# Out:
# array([ -3,  -6, -20])

# %%
from matplotlib import pyplot as plt 

plt.plot(Y_pred, X) 
plt.scatter(X, Y_pred) 
# function to show the plot 
plt.show()
